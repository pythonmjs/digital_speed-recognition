# %%
import os
import shutil

dirpath = os.path.join('.', 'speed')
if os.path.exists(dirpath) and os.path.isdir(dirpath):
    shutil.rmtree(dirpath)

dirpath = os.path.join('.', 'video_to_frame')
if os.path.exists(dirpath) and os.path.isdir(dirpath):
    shutil.rmtree(dirpath)

pd='/home/monil/Desktop/application/speed_1'   
d='video_to_frame'                                             #create directory
path = os.path.join(pd, d) 
os.mkdir(path)

pd='/home/monil/Desktop/application/speed_1'   
d='speed'                                             #create directory
path = os.path.join(pd, d) 
os.mkdir(path)

dirpath = os.path.join('.', 'date')
if os.path.exists(dirpath) and os.path.isdir(dirpath):
    shutil.rmtree(dirpath)

pd='/home/monil/Desktop/application/speed_1'   
d='date'                                             #create directory
path = os.path.join(pd, d) 
os.mkdir(path)

dirpath = os.path.join('.', 'time')
if os.path.exists(dirpath) and os.path.isdir(dirpath):
    shutil.rmtree(dirpath)

pd='/home/monil/Desktop/application/speed_1'   
d='time'                                             #create directory
path = os.path.join(pd, d) 
os.mkdir(path)

# %%
#run the all cells one by one. 
#Initlally, the video_to_frame directory is created manually as it updates frames everytime.


import cv2
import os
import glob
vidcap = cv2.VideoCapture('./videos/20190926_161719_NF.mp4') # path of input video
def getFrame(sec):
    vidcap.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = vidcap.read()
    if hasFrames:
        cv2.imwrite("./video_to_frame/"+str(count)+".jpg", image)   #where the video to frame will be created
    return hasFrames
sec = 0
frameRate = 1
count=1
success = getFrame(sec)

while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

# %%
import glob
import os
from PIL import Image
path="./video_to_frame/"
path1="./date/"
for i in os.listdir(path):
    img = Image.open(path+i)
    cropp=img.crop((10,1052,200,1080))
    newsize = (600, 300) 
    im1 = cropp.resize(newsize) 
    im1.save(path1+str(i))
path2="./time/"
for i in os.listdir(path):
    img = Image.open(path+i)
    cropp=img.crop((210,1052,370,1080))
    newsize = (700, 300) 
    im1 = cropp.resize(newsize) 
    im1.save(path2+str(i))
path3="./speed/"
for i in os.listdir(path):
    img = Image.open(path+i)
    cropp=img.crop((382,1052,452,1080))
    newsize = (600, 300) 
    im1 = cropp.resize(newsize) 
    im1.save(path3+str(i))

# %%
import cv2
import numpy as np
import os, os.path
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
def character_segmentation(img_path,count):
    img = cv2.imread(img_path)
    im2 = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
   # cv2.imshow('in', im2)
    ret2,thresh = cv2.threshold(im2, 127, 255,cv2.THRESH_OTSU)
    ret3,thresh2 = cv2.threshold(thresh,127,255,cv2.THRESH_BINARY)
    #cv2.imshow('threshoulding',thresh2)
    directory = str(count)
    parent_dir = './date/'  #applying image processing techniques to the images
    path = os.path.join(parent_dir, directory) 
    #print(path)
    os.mkdir(path)
    # find contours
    im2, ctrs, hier = cv2.findContours(thresh2.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # sort contours
    sorted_ctrs = sorted(ctrs, key=lambda ctr: cv2.boundingRect(ctr)[0])
    for i, ctr in enumerate(sorted_ctrs):
        # Get bounding box
        x, y, w, h = cv2.boundingRect(ctr)

        # Getting ROI
        roi = thresh2[y:y + h, x:x + w]

        # show ROI
        # cv2.imshow('segment no:'+str(i),roi)
        cv2.rectangle(thresh2, (x, y), (x + w, y + h), (0,0,0),1)
        # cv2.waitKey(0)


        
        cv2.imwrite(path+'/'+'{}.jpg'.format(i), roi)

    #cv2.imshow('marked areas',thresh2)

    cv2.waitKey(0)
    return



DIR = './date/'
x=(len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]))
y=x+1
i=1
while(i<y):
    character_segmentation("./date/"+str(i)+".jpg",i)
    i=i+1

# %%
import os
mydir='./date/'
filelist = [ f for f in os.listdir(mydir) if f.endswith(".jpg") ]
for f in filelist:
    os.remove(os.path.join(mydir, f))

# %%
import cv2
import numpy as np
import os, os.path
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
def character_segmentation(img_path,count):
    img = cv2.imread(img_path)
    im2 = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
   # cv2.imshow('in', im2)
    ret2,thresh = cv2.threshold(im2, 127, 255,cv2.THRESH_OTSU)
    ret3,thresh2 = cv2.threshold(thresh,127,255,cv2.THRESH_BINARY)
    #cv2.imshow('threshoulding',thresh2)
    directory = str(count)
    parent_dir = './time/'  #applying image processing techniques to the images
    path = os.path.join(parent_dir, directory) 
    #print(path)
    os.mkdir(path)
    # find contours
    im2, ctrs, hier = cv2.findContours(thresh2.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # sort contours
    sorted_ctrs = sorted(ctrs, key=lambda ctr: cv2.boundingRect(ctr)[0])
    for i, ctr in enumerate(sorted_ctrs):
        # Get bounding box
        x, y, w, h = cv2.boundingRect(ctr)

        # Getting ROI
        roi = thresh2[y:y + h, x:x + w]

        # show ROI
        # cv2.imshow('segment no:'+str(i),roi)
        cv2.rectangle(thresh2, (x, y), (x + w, y + h), (0,0,0),1)
        # cv2.waitKey(0)


        
        cv2.imwrite(path+'/'+'{}.jpg'.format(i), roi)

    #cv2.imshow('marked areas',thresh2)

    cv2.waitKey(0)
    return



DIR = './time/'
x=(len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]))
y=x+1
i=1
while(i<y):
    character_segmentation("./time/"+str(i)+".jpg",i)
    i=i+1

# %%
import os
mydir='./time/'
filelist = [ f for f in os.listdir(mydir) if f.endswith(".jpg") ]
for f in filelist:
    os.remove(os.path.join(mydir, f))

# %%
import cv2
import numpy as np
import os, os.path
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
def character_segmentation(img_path,count):
    img = cv2.imread(img_path)
    im2 = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
   # cv2.imshow('in', im2)
    ret2,thresh = cv2.threshold(im2, 127, 255,cv2.THRESH_OTSU)
    ret3,thresh2 = cv2.threshold(thresh,127,255,cv2.THRESH_BINARY)
    #cv2.imshow('threshoulding',thresh2)
    directory = str(count)
    parent_dir = './speed/'  #applying image processing techniques to the images
    path = os.path.join(parent_dir, directory) 
    #print(path)
    os.mkdir(path)
    # find contours
    im2, ctrs, hier = cv2.findContours(thresh2.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # sort contours
    sorted_ctrs = sorted(ctrs, key=lambda ctr: cv2.boundingRect(ctr)[0])
    for i, ctr in enumerate(sorted_ctrs):
        # Get bounding box
        x, y, w, h = cv2.boundingRect(ctr)

        # Getting ROI
        roi = thresh2[y:y + h, x:x + w]

        # show ROI
        # cv2.imshow('segment no:'+str(i),roi)
        cv2.rectangle(thresh2, (x, y), (x + w, y + h), (0,0,0),1)
        # cv2.waitKey(0)


        
        cv2.imwrite(path+'/'+'{}.jpg'.format(i), roi)

    #cv2.imshow('marked areas',thresh2)

    cv2.waitKey(0)
    return



DIR = './speed/'
x=(len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]))
y=x+1
i=1
while(i<y):
    character_segmentation("./speed/"+str(i)+".jpg",i)
    i=i+1

# %%
import os
mydir='./speed/'
filelist = [ f for f in os.listdir(mydir) if f.endswith(".jpg") ]
for f in filelist:
    os.remove(os.path.join(mydir, f))

# %%
import os
import glob
from PIL import Image, ImageOps
def add_border(input_image, output_image, border):
    img = Image.open(input_image)
    bimg = ImageOps.expand(img, border=border)
    bimg.save(output_image)
    

def digit_path(path):
    f=os.listdir(path)
    d=len(f)
    for i in range(0,d):
        in_img = path+str(i)+'.jpg'
        add_border(in_img, output_image=in_img, border=100)
        

h=1
dir1='./date/'
dir2='./time/'
dir3='./speed/'
f=os.listdir(dir1)
d=len(f)+1
while(h<d):
    digit_path("./date/"+str(h)+"/")
    h=h+1
h=1
ff=os.listdir(dir2)
dd=len(ff)+1
while(h<dd):
    digit_path("./time/"+str(h)+"/")
    h=h+1
h=1
f=os.listdir(dir3)
d=len(f)+1
while(h<d):
    digit_path("./speed/"+str(h)+"/")
    h=h+1

# %%
#NOISE REMOVAL IMAGES
import os
import glob
import cv2
import numpy as np
h=0
dir1='./date/'
dir2='./time/'
dir3='./speed/'
f=os.listdir(dir1)
d=len(f)
speed=[]
data=[]
iip='./date/'
while(h<d):
    h=h+1
    path=iip+str(h)+'/'
    num=[]
    ff=os.listdir(path)
    dd=len(ff)
    for i in range(0,dd):
        pathp=path+str(i)+'.jpg'
        img = cv2.imread(pathp, cv2.IMREAD_GRAYSCALE)
        n_white_pix = np.sum(img == 255)
        if(n_white_pix<1500):
            os.remove(pathp)
h=0
f=os.listdir(dir2)
d=len(f)
speed=[]
data=[]
iip='./time/'
while(h<d):
    h=h+1
    path=iip+str(h)+'/'
    num=[]
    ff=os.listdir(path)
    dd=len(ff)
    for i in range(0,dd):
        pathp=path+str(i)+'.jpg'
        img = cv2.imread(pathp, cv2.IMREAD_GRAYSCALE)
        n_white_pix = np.sum(img == 255)
        if(n_white_pix<1000):
            os.remove(pathp)
h=0
f=os.listdir(dir3)
d=len(f)
speed=[]
data=[]
iip='./speed/'
while(h<d):
    h=h+1
    path=iip+str(h)+'/'
    num=[]
    ff=os.listdir(path)
    dd=len(ff)
    for i in range(0,dd):
        pathp=path+str(i)+'.jpg'
        img = cv2.imread(pathp, cv2.IMREAD_GRAYSCALE)
        n_white_pix = np.sum(img == 255)
        if(n_white_pix<700):
            os.remove(pathp)

# %%
# MODIFIED


#DIGIT RECOGNITIONN
import os
import glob
import cv2
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import load_model
import tensorflow as tf
 
# load and prepare the image
def load_image(filename):
    
    # load the image
    img = load_img(filename, grayscale=True, target_size=(28,28))
    # convert to array
    img = img_to_array(img)
    # reshape into a single sample with 1 channel
    img = img.reshape(1, 28,28, 1)
    # prepare pixel data
    img = img.astype('float32')
    img = img / 255.0
    return img
 
def first(x):
    return x[1:]

def prepare(filepath):
    IMG_SIZE = 32  # 50 in txt-based
    img_array = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
    new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
    return new_array.reshape(-1, IMG_SIZE, IMG_SIZE, 1)


def fun0_8(filename):
    CATEGORIES = ["0", "8"]
    model = tf.keras.models.load_model('/content/drive/My Drive/Colab Notebooks/0_8mod.model')

    prediction = model.predict([prepare(filename)])
  # will be a list in a list.
    return (CATEGORIES[int(prediction[0])])


def run_example():
    # load the image
    h=0
    dir='/content/drive/My Drive/Colab Notebooks/date/'
    f=os.listdir(dir)
    d=len(f)
    speed=[]
    data=[]
    iip='/content/drive/My Drive/Colab Notebooks/date/'
    while(h<d):
        h=h+1
        path=iip+str(h)+'/'
        num=[]
        ff=os.listdir(path)
        ff.sort()
        sorted(ff,key=first)

        for filename in sorted(ff, key=first):
            filename=path+filename
            #pathp=path+str(i)+'.jpg'
            img = load_image(filename)
            # load model
            model = load_model('/content/drive/My Drive/Colab Notebooks/cnn2.h5')            #using model using MNIST dataset
            # predict the class
            digit = model.predict_classes(img)
            
            if(digit[0]==9 or digit[0]==3 ):
                model = load_model('/content/drive/My Drive/Colab Notebooks/cnn1.h5')         #using previous one
                digitx = model.predict_classes(img)
                if(digit[0]==9 and digitx[0]==8):
                    digit[0]=fun0_8(filename)
                if((digit[0]!=digitx[0]) and (digitx[0]!=8)):
                    digit[0]=digitx[0]        
                        
                
            num.append(digit[0])
        speed.append(num)
       
        lst_to_str=''.join(map(str,num))
        data.append(lst_to_str)     
        print(data)
    for i in range(0, len(data)): 
        data[i] = int(data[i]) 
    dss=[]
    for i in data:
        i=(str(int(str(i)[:4]))+'-'+str(int(str(i)[4:6]))+'-'+str(int(str(i)[6:8])))
        dss.append(i)
    return dss

date_q=run_example()
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# MODIFIED


#DIGIT RECOGNITIONN
import os
import glob
import cv2
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import load_model
import tensorflow as tf
 
# load and prepare the image
def load_image(filename):
    
    # load the image
    img = load_img(filename, grayscale=True, target_size=(28,28))
    # convert to array
    img = img_to_array(img)
    # reshape into a single sample with 1 channel
    img = img.reshape(1, 28,28, 1)
    # prepare pixel data
    img = img.astype('float32')
    img = img / 255.0
    return img
 
def first(x):
    return x[1:]

def prepare(filepath):
    IMG_SIZE = 32  # 50 in txt-based
    img_array = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
    new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
    return new_array.reshape(-1, IMG_SIZE, IMG_SIZE, 1)


def fun0_8(filename):
    CATEGORIES = ["0", "8"]
    model = tf.keras.models.load_model('/content/drive/My Drive/Colab Notebooks/0_8mod.model')

    prediction = model.predict([prepare(filename)])
  # will be a list in a list.
    return (CATEGORIES[int(prediction[0])])


def run_example():
    # load the image
    h=0
    dir='/content/drive/My Drive/Colab Notebooks/time/'
    f=os.listdir(dir)
    d=len(f)
    speed=[]
    data=[]
    iip='/content/drive/My Drive/Colab Notebooks/time/'
    while(h<d):
        h=h+1
        path=iip+str(h)+'/'
        num=[]
        ff=os.listdir(path)
        ff.sort()
        sorted(ff,key=first)

        for filename in sorted(ff, key=first):
            filename=path+filename
            #pathp=path+str(i)+'.jpg'
            img = load_image(filename)
            # load model
            model = load_model('/content/drive/My Drive/Colab Notebooks/cnn2.h5')            #using model using MNIST dataset
            # predict the class
            digit = model.predict_classes(img)
            
            if(digit[0]==9 or digit[0]==3 ):
                model = load_model('/content/drive/My Drive/Colab Notebooks/cnn1.h5')         #using previous one
                digitx = model.predict_classes(img)
                if(digit[0]==9 and digitx[0]==8):
                    digit[0]=fun0_8(filename)
                if((digit[0]!=digitx[0]) and (digitx[0]!=8)):
                    digit[0]=digitx[0]        
                        
                
            num.append(digit[0])
        speed.append(num)
       
        lst_to_str=''.join(map(str,num))
        data.append(lst_to_str)     
        print(data)
    for i in range(0, len(data)): 
        data[i] = int(data[i]) 
    dss2=[]
    for i in data:
        i=(str(int(str(i)[:2]))+':'+str(int(str(i)[2:4]))+':'+str(int(str(i)[4:6])))
        dss2.append(i)
    return dss2

time_q=run_example()

# %%
# MODIFIED


#DIGIT RECOGNITIONN
import os
import glob
import cv2
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import load_model
import tensorflow as tf
 
# load and prepare the image
def load_image(filename):
    
    # load the image
    img = load_img(filename, grayscale=True, target_size=(28,28))
    # convert to array
    img = img_to_array(img)
    # reshape into a single sample with 1 channel
    img = img.reshape(1, 28,28, 1)
    # prepare pixel data
    img = img.astype('float32')
    img = img / 255.0
    return img
 
def first(x):
    return x[1:]

def prepare(filepath):
    IMG_SIZE = 32  # 50 in txt-based
    img_array = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
    new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
    return new_array.reshape(-1, IMG_SIZE, IMG_SIZE, 1)


def fun0_8(filename):
    CATEGORIES = ["0", "8"]
    model = tf.keras.models.load_model('/content/drive/My Drive/Colab Notebooks/0_8mod.model')

    prediction = model.predict([prepare(filename)])
  # will be a list in a list.
    return (CATEGORIES[int(prediction[0])])


def run_example():
    # load the image
    h=0
    dir='/content/drive/My Drive/Colab Notebooks/speed/'
    f=os.listdir(dir)
    d=len(f)
    speed=[]
    data3=[]
    iip='/content/drive/My Drive/Colab Notebooks/speed/'
    while(h<d):
        h=h+1
        path=iip+str(h)+'/'
        num=[]
        ff=os.listdir(path)
        ff.sort()
        sorted(ff,key=first)

        for filename in sorted(ff, key=first):
            filename=path+filename
            #pathp=path+str(i)+'.jpg'
            img = load_image(filename)
            # load model
            model = load_model('/content/drive/My Drive/Colab Notebooks/cnn2.h5')            #using model using MNIST dataset
            # predict the class
            digit = model.predict_classes(img)
            
            if(digit[0]==9 or digit[0]==3 ):
                model = load_model('/content/drive/My Drive/Colab Notebooks/cnn1.h5')         #using previous one
                digitx = model.predict_classes(img)
                if(digit[0]==9 and digitx[0]==8):
                    digit[0]=fun0_8(filename)
                if((digit[0]!=digitx[0]) and (digitx[0]!=8)):
                    digit[0]=digitx[0]        
                        
                
            num.append(digit[0])
        speed.append(num)
       
        lst_to_str=''.join(map(str,num))
        data3.append(lst_to_str)
        
        print(data3)
    
    
    for i in range(0, len(data3)): 
        data3[i] = int(data3[i]) 
    for i in range(0,len(data3)):
        if(data3[i]>400):
            data3[i]=str("NA")
    
    return data3



speed_q=run_example()

# %%
import csv
x=["Date","Time","Speed"]
rows = zip(date_q,time_q,speed_q)
with open("recognition_speed.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerow(x)
    for row in rows:
        writer.writerow(row)
# Out:
# average speed :  142

# %%
import os
import glob
import cv2
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import load_model
import tensorflow as tf
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
